# %% [markdown]
# # İş Problemi

# %% [markdown]
# Maaş bilgileri ve 1986 yılına ait kariyer istatistikleri paylaşılan beyzbol oyuncularının maaş tahminleri için bir makine öğrenmesi modeli geliştiriniz.

# %% [markdown]
# # Veri Seti Hikayesi

# %% [markdown]
# Bu veri seti orijinal olarak Carnegie Mellon Üniversitesi'nde bulunan StatLib kütüphanesinden alınmıştır. Veri seti 1988 ASA Grafik Bölümü Poster Oturumu'nda kullanılan verilerin bir parçasıdır. Maaş verileri
# orijinal olarak Sports Illustrated, 20 Nisan 1987'den alınmıştır. 1986 ve kariyer istatistikleri, Collier Books, Macmillan Publishing Company, New York tarafından yayınlanan 1987 Beyzbol Ansiklopedisi
# Güncellemesinden elde edilmiştir.

# %%
# AtBat: 1986-1987 sezonunda bir beyzbol sopası ile topa yapılan vuruş sayısı
# Hits: 1986-1987 sezonundaki isabet sayısı
# HmRun: 1986-1987 sezonundaki en değerli vuruş sayısı
# Runs: 1986-1987 sezonunda takımına kazandırdığı sayı
# RBI: Bir vurucunun vuruş yaptıgında koşu yaptırdığı oyuncu sayısı
# Walks: Karşı oyuncuya yaptırılan hata sayısı
# Years: Oyuncunun major liginde oynama süresi (sene)
# CAtBat: Oyuncunun kariyeri boyunca topa vurma sayısı
# CHits: Oyuncunun kariyeri boyunca yaptığı isabetli vuruş sayısı
# CHmRun: Oyucunun kariyeri boyunca yaptığı en değerli sayısı
# CRuns: Oyuncunun kariyeri boyunca takımına kazandırdığı sayı
# CRBI: Oyuncunun kariyeri boyunca koşu yaptırdırdığı oyuncu sayısı
# CWalks: Oyuncun kariyeri boyunca karşı oyuncuya yaptırdığı hata sayısı
# League: Oyuncunun sezon sonuna kadar oynadığı ligi gösteren A ve N seviyelerine sahip bir faktör
# Division: 1986 sonunda oyuncunun oynadığı pozisyonu gösteren E ve W seviyelerine sahip bir faktör
# PutOuts: Oyun icinde takım arkadaşınla yardımlaşma
# Assits: 1986-1987 sezonunda oyuncunun yaptığı asist sayısı
# Errors: 1986-1987 sezonundaki oyuncunun hata sayısı
# Salary: Oyuncunun 1986-1987 sezonunda aldığı maaş(bin uzerinden)
# NewLeague: 1987 sezonunun başında oyuncunun ligini gösteren A ve N seviyelerine sahip bir faktör

# %% [markdown]
# # Görev
#
# • Veri ön işleme,
#
# • Özellik mühendisliği
#
# işlemleri gerçekleştirerek maaş tahmin modeli geliştiriniz.

# %%
import numpy as np
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler, RobustScaler

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate, cross_val_score, validation_curve

from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.width', 500)

# %%
from pandas.core.common import SettingWithCopyWarning
from sklearn.exceptions import ConvergenceWarning

warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action="ignore", category=ConvergenceWarning)
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
df = pd.read_csv('/Users/mericgenc/Desktop/Python - Data Science/Miuul Data Scientist Path/06 - Machine Learning/01_regression/02_case_salary_prediction/01_dataset/hitters.csv')
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    293    66      1    30   29     14      1     293     66       1     30    29      14      A        E      446       33      20     NaN         A
# 1    315    81      7    24   38     39     14    3449    835      69    321   414     375      N        W      632       43      10 475.000         N
# 2    479   130     18    66   72     76      3    1624    457      63    224   266     263      A        W      880       82      14 480.000         A
# 3    496   141     20    65   78     37     11    5628   1575     225    828   838     354      N        E      200       11       3 500.000         N
# 4    321    87     10    39   42     30      2     396    101      12     48    46      33      N        E      805       40       4  91.500         N

# %%
# GELİŞMİŞ FONKSİYONEL KEŞİFÇİ VERİ ANALİZİ (ADVANCED FUNCTIONAL EDA)

# %%
#############################################
# 1. Genel Resim
# 2. Kategorik Değişken Analizi (Analysis of Categorical Variables)
# 3. Sayısal Değişken Analizi (Analysis of Numerical Variables)
# 4. Hedef Değişken Analizi (Analysis of Target Variable)
# 5. Korelasyon Analizi (Analysis of Correlation)
#############################################

# %%
# 1. Genel Resim

# %%
def check_df(dataframe, head=5):
    print("##################### Shape #####################")
    print(dataframe.shape)

    print("##################### Types #####################")
    print(dataframe.dtypes)

    print("##################### Head #####################")
    print(dataframe.head(head))

    print("##################### Tail #####################")
    print(dataframe.tail(head))

    print("##################### NA #####################")
    print(dataframe.isnull().sum())

    print("##################### Quantiles #####################")
    print(dataframe.quantile([0, 0.05, 0.50, 0.95, 0.99, 1]).T)

# %%
check_df(df)
# Out:
# ##################### Shape #####################
# (322, 20)
# ##################### Types #####################
# AtBat          int64
# Hits           int64
# HmRun          int64
# Runs           int64
# RBI            int64
# Walks          int64
# Years          int64
# CAtBat         int64
# CHits          int64
# CHmRun         int64
# CRuns          int64
# CRBI           int64
# CWalks         int64
# League        object
# Division      object
# PutOuts        int64
# Assists        int64
# Errors         int64
# Salary       float64
# NewLeague     object
# dtype: object
# ##################### Head #####################
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    293    66      1    30   29     14      1     293     66       1     30    29      14      A        E      446       33      20     NaN         A
# 1    315    81      7    24   38     39     14    3449    835      69    321   414     375      N        W      632       43      10 475.000         N
# 2    479   130     18    66   72     76      3    1624    457      63    224   266     263      A        W      880       82      14 480.000         A
# 3    496   141     20    65   78     37     11    5628   1575     225    828   838     354      N        E      200       11       3 500.000         N
# 4    321    87     10    39   42     30      2     396    101      12     48    46      33      N        E      805       40       4  91.500         N
# ##################### Tail #####################
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors   Salary NewLeague
# 317    497   127      7    65   48     37      5    2703    806      32    379   311     138      N        E      325        9       3  700.000         N
# 318    492   136      5    76   50     94     12    5511   1511      39    897   451     875      A        E      313      381      20  875.000         A
# 319    475   126      3    61   43     52      6    1700    433       7    217    93     146      A        W       37      113       7  385.000         A
# 320    573   144      9    85   60     78      8    3198    857      97    470   420     332      A        E     1314      131      12  960.000         A
# 321    631   170      9    77   44     31     11    4908   1457      30    775   357     249      A        W      408        4       3 1000.000         A
# ##################### NA #####################
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64
# ##################### Quantiles #####################
#          0.000   0.050    0.500    0.950    0.990     1.000
# AtBat   16.000 161.000  379.500  609.900  658.590   687.000
# Hits     1.000  39.000   96.000  174.000  210.790   238.000
# HmRun    0.000   0.000    8.000   28.950   33.000    40.000
# Runs     0.000  17.000   48.000   94.000  107.790   130.000
# RBI      0.000  14.000   44.000   96.000  112.370   121.000
# Walks    0.000  11.050   35.000   78.000   93.580   105.000
# Years    1.000   1.000    6.000   17.000   19.790    24.000
# CAtBat  19.000 216.500 1928.000 7125.600 8749.970 14053.000
# CHits    4.000  54.000  508.000 2017.150 2500.340  4256.000
# CHmRun   0.000   2.000   37.500  265.650  373.120   548.000
# CRuns    1.000  27.000  247.000 1032.300 1174.370  2165.000
# CRBI     0.000  22.050  220.500 1071.750 1310.850  1659.000
# CWalks   0.000  15.050  170.500  817.600 1139.140  1566.000
# PutOuts  0.000  33.200  212.000  910.650 1301.190  1378.000
# Assists  0.000   0.000   39.500  431.450  478.160   492.000
# Errors   0.000   0.000    6.000   20.000   25.790    32.000
# Salary  67.500  86.600  425.000 1346.000 2032.887  2460.000

# %%
def grab_col_names(dataframe, cat_th=10, car_th=20):
    """

    Veri setindeki kategorik, numerik ve kategorik fakat kardinal değişkenlerin isimlerini verir.
    Not: Kategorik değişkenlerin içerisine numerik görünümlü kategorik değişkenler de dahildir.

    Parameters
    ------
        dataframe: dataframe
                Değişken isimleri alınmak istenilen dataframe
        cat_th: int, optional
                numerik fakat kategorik olan değişkenler için sınıf eşik değeri
        car_th: int, optinal
                kategorik fakat kardinal değişkenler için sınıf eşik değeri

    Returns
    ------
        cat_cols: list
                Kategorik değişken listesi
        num_cols: list
                Numerik değişken listesi
        cat_but_car: list
                Kategorik görünümlü kardinal değişken listesi

    Examples
    ------
        import seaborn as sns
        df = sns.load_dataset("iris")
        print(grab_col_names(df))


    Notes
    ------
        cat_cols + num_cols + cat_but_car = toplam değişken sayısı
        num_but_cat cat_cols'un içerisinde.
        Return olan 3 liste toplamı toplam değişken sayısına eşittir: cat_cols + num_cols + cat_but_car = değişken sayısı

    """


    # cat_cols, cat_but_car
    cat_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"]
    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and
                   dataframe[col].dtypes != "O"]
    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and
                   dataframe[col].dtypes == "O"]
    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    # num_cols
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"]
    num_cols = [col for col in num_cols if col not in num_but_cat]

    print(f"Observations: {dataframe.shape[0]}")
    print(f"Variables: {dataframe.shape[1]}")
    print(f'cat_cols: {len(cat_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'cat_but_car: {len(cat_but_car)}')
    print(f'num_but_cat: {len(num_but_cat)}')
    return cat_cols, num_cols, cat_but_car

cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 322
# Variables: 20
# cat_cols: 3
# num_cols: 17
# cat_but_car: 0
# num_but_cat: 0

# %%
# 2. Kategorik Değişken Analizi (Analysis of Categorical Variables)

# %%
def cat_summary(dataframe, col_name, plot=False):

    print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                        "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)}))
    print("##########################################")

    if plot:
        sns.countplot(x=dataframe[col_name], data=dataframe)
        plt.show()

# %%
for col in cat_cols:
    cat_summary(df, col, plot=True)
# Out:
#    League  Ratio
# A     175 54.348
# N     147 45.652
# ##########################################
#    Division  Ratio
# W       165 51.242
# E       157 48.758
# ##########################################
#    NewLeague  Ratio
# A        176 54.658
# N        146 45.342
# ##########################################

# %%
# 3. Sayısal Değişken Analizi (Analysis of Numerical Variables)

# %%
def num_summary(dataframe, numerical_col, plot=False):

    quantiles = [0.05, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 0.95, 0.99]

    print(dataframe[numerical_col].describe(quantiles).T)

    if plot:
        dataframe[numerical_col].hist(bins=20)
        plt.xlabel(numerical_col)
        plt.title(numerical_col)
        plt.show()

# %%
for col in num_cols:
    num_summary(df, col, plot=True)
# Out:
# count   322.000
# mean    380.929
# std     153.405
# min      16.000
# 5%      161.000
# 10%     194.100
# 20%     221.800
# 30%     281.300
# 40%     321.800
# 50%     379.500
# 60%     430.200
# 70%     490.000
# 80%     535.600
# 90%     584.900
# 95%     609.900
# 99%     658.590
# max     687.000
# Name: AtBat, dtype: float64
# count   322.000
# mean    101.025
# std      46.455
# min       1.000
# 5%       39.000
# 10%      45.100
# 20%      57.000
# 30%      70.000
# 40%      82.000
# 50%      96.000
# 60%     113.000
# 70%     128.700
# 80%     144.000
# 90%     163.000
# 95%     174.000
# 99%     210.790
# max     238.000
# Name: Hits, dtype: float64
# count   322.000
# mean     10.770
# std       8.709
# min       0.000
# 5%        0.000
# 10%       1.000
# 20%       3.000
# 30%       5.000
# 40%       6.000
# 50%       8.000
# 60%      10.600
# 70%      14.000
# 80%      18.000
# 90%      24.000
# 95%      28.950
# 99%      33.000
# max      40.000
# Name: HmRun, dtype: float64
# count   322.000
# mean     50.910
# std      26.024
# min       0.000
# 5%       17.000
# 10%      20.100
# 20%      27.000
# 30%      33.000
# 40%      41.000
# 50%      48.000
# 60%      55.600
# 70%      66.000
# 80%      75.800
# 90%      89.000
# 95%      94.000
# 99%     107.790
# max     130.000
# Name: Runs, dtype: float64
# count   322.000
# mean     48.028
# std      26.167
# min       0.000
# 5%       14.000
# 10%      19.000
# 20%      26.000
# 30%      30.000
# 40%      36.400
# 50%      44.000
# 60%      49.000
# 70%      58.000
# 80%      73.000
# 90%      86.000
# 95%      96.000
# 99%     112.370
# max     121.000
# Name: RBI, dtype: float64
# count   322.000
# mean     38.742
# std      21.639
# min       0.000
# 5%       11.050
# 10%      15.000
# 20%      20.000
# 30%      24.000
# 40%      30.000
# 50%      35.000
# 60%      40.000
# 70%      48.700
# 80%      59.000
# 90%      69.900
# 95%      78.000
# 99%      93.580
# max     105.000
# Name: Walks, dtype: float64
# count   322.000
# mean      7.444
# std       4.926
# min       1.000
# 5%        1.000
# 10%       2.000
# 20%       3.000
# 30%       4.000
# 40%       5.000
# 50%       6.000
# 60%       7.600
# 70%      10.000
# 80%      12.000
# 90%      15.000
# 95%      17.000
# 99%      19.790
# max      24.000
# Name: Years, dtype: float64
# count     322.000
# mean     2648.683
# std      2324.206
# min        19.000
# 5%        216.500
# 10%       342.200
# 20%       667.600
# 30%       963.400
# 40%      1402.200
# 50%      1928.000
# 60%      2654.000
# 70%      3365.000
# 80%      4483.000
# 90%      6123.400
# 95%      7125.600
# 99%      8749.970
# max     14053.000
# Name: CAtBat, dtype: float64
# count    322.000
# mean     717.571
# std      654.473
# min        4.000
# 5%        54.000
# 10%       86.000
# 20%      164.600
# 30%      238.000
# 40%      355.800
# 50%      508.000
# 60%      708.200
# 70%      911.100
# 80%     1229.200
# 90%     1659.600
# 95%     2017.150
# 99%     2500.340
# max     4256.000
# Name: CHits, dtype: float64
# count   322.000
# mean     69.491
# std      86.266
# min       0.000
# 5%        2.000
# 10%       4.000
# 20%      10.200
# 30%      16.300
# 40%      27.400
# 50%      37.500
# 60%      51.200
# 70%      72.400
# 80%     103.800
# 90%     194.900
# 95%     265.650
# 99%     373.120
# max     548.000
# Name: CHmRun, dtype: float64
# count    322.000
# mean     358.795
# std      334.106
# min        1.000
# 5%        27.000
# 10%       38.100
# 20%       80.400
# 30%      117.300
# 40%      181.000
# 50%      247.000
# 60%      333.000
# 70%      443.400
# 80%      627.200
# 90%      895.700
# 95%     1032.300
# 99%     1174.370
# max     2165.000
# Name: CRuns, dtype: float64
# count    322.000
# mean     330.118
# std      333.220
# min        0.000
# 5%        22.050
# 10%       34.100
# 20%       70.200
# 30%      106.300
# 40%      149.000
# 50%      220.500
# 60%      303.600
# 70%      379.100
# 80%      496.200
# 90%      861.600
# 95%     1071.750
# 99%     1310.850
# max     1659.000
# Name: CRBI, dtype: float64
# count    322.000
# mean     260.239
# std      267.058
# min        0.000
# 5%        15.050
# 10%       30.100
# 20%       55.000
# 30%       82.000
# 40%      117.400
# 50%      170.500
# 60%      226.600
# 70%      300.700
# 80%      421.000
# 90%      643.900
# 95%      817.600
# 99%     1139.140
# max     1566.000
# Name: CWalks, dtype: float64
# count    322.000
# mean     288.938
# std      280.705
# min        0.000
# 5%        33.200
# 10%       62.200
# 20%       99.600
# 30%      132.000
# 40%      167.000
# 50%      212.000
# 60%      257.400
# 70%      303.000
# 80%      365.800
# 90%      685.600
# 95%      910.650
# 99%     1301.190
# max     1378.000
# Name: PutOuts, dtype: float64
# count   322.000
# mean    106.913
# std     136.855
# min       0.000
# 5%        0.000
# 10%       2.000
# 20%       5.200
# 30%       9.000
# 40%      15.400
# 50%      39.500
# 60%      76.800
# 70%     134.800
# 80%     210.800
# 90%     353.300
# 95%     431.450
# 99%     478.160
# max     492.000
# Name: Assists, dtype: float64
# count   322.000
# mean      8.040
# std       6.368
# min       0.000
# 5%        0.000
# 10%       1.000
# 20%       3.000
# 30%       4.000
# 40%       5.000
# 50%       6.000
# 60%       8.000
# 70%      10.000
# 80%      13.000
# 90%      17.000
# 95%      20.000
# 99%      25.790
# max      32.000
# Name: Errors, dtype: float64
# count    263.000
# mean     535.926
# std      451.119
# min       67.500
# 5%        86.600
# 10%      100.000
# 20%      155.000
# 30%      221.000
# 40%      300.000
# 50%      425.000
# 60%      538.000
# 70%      700.000
# 80%      809.000
# 90%     1048.667
# 95%     1346.000
# 99%     2032.887
# max     2460.000
# Name: Salary, dtype: float64

# %%
# 4. Hedef Değişken Analizi (Analysis of Target Variables

# %%
def target_summary_with_cat(dataframe, target, categorical_col):

    print(pd.DataFrame({"TARGET_MEAN": dataframe.groupby(categorical_col)[target].mean()}), end="\n\n\n")

# %%
for col in cat_cols:
    target_summary_with_cat(df, "Salary", col)
# Out:
#         TARGET_MEAN
# League
# A           542.000
# N           529.118
#
#
#           TARGET_MEAN
# Division
# E             624.271
# W             450.877
#
#
#            TARGET_MEAN
# NewLeague
# A              537.113
# N              534.554

# %%
# 5. Korelasyon Analizi (Analysis of Correlation)

# %%
def high_correlated_cols(dataframe, plot=False, corr_th=0.90):
    corr = dataframe.corr()
    cor_matrix = corr.abs()
    upper_triangle_matrix = cor_matrix.where(np.triu(np.ones(cor_matrix.shape), k=1).astype(np.bool))
    drop_list = [col for col in upper_triangle_matrix.columns if any(upper_triangle_matrix[col] > corr_th)]
    if plot:
        import seaborn as sns
        import matplotlib.pyplot as plt
        sns.set(rc={'figure.figsize': (15, 15)})
        sns.heatmap(corr, cmap="RdBu")
        plt.show()
    return drop_list

# %%
high_correlated_cols(df, plot=True)
# Out:
# ['Hits', 'Runs', 'CAtBat', 'CHits', 'CRuns', 'CRBI', 'CWalks']

# %%
# 6. Outliers (Aykırı Değerler)

# %%
def outlier_thresholds(dataframe, col_name, q1=0.25, q3=0.75):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False

def replace_with_thresholds(dataframe, variable):
    low_limit, up_limit = outlier_thresholds(dataframe, variable)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %%
for col in num_cols:
    print(col, check_outlier(df, col))
# Out:
# AtBat False
# Hits False
# HmRun True
# Runs True
# RBI True
# Walks True
# Years True
# CAtBat True
# CHits True
# CHmRun True
# CRuns True
# CRBI True
# CWalks True
# PutOuts True
# Assists True
# Errors True
# Salary True

# %%
for col in num_cols:
    if check_outlier(df, col):
        replace_with_thresholds(df, col)

# %%
for col in num_cols:
    print(col, check_outlier(df, col))
# Out:
# AtBat False
# Hits False
# HmRun False
# Runs False
# RBI False
# Walks False
# Years False
# CAtBat False
# CHits False
# CHmRun False
# CRuns False
# CRBI False
# CWalks False
# PutOuts False
# Assists False
# Errors False
# Salary False

# %%
# 7. Missing Values (Eksik Değerler)

# %%
def missing_values_table(dataframe, na_name=False):
    na_columns = [col for col in dataframe.columns if dataframe[col].isnull().sum() > 0]
    n_miss = dataframe[na_columns].isnull().sum().sort_values(ascending=False)
    ratio = (dataframe[na_columns].isnull().sum() / dataframe.shape[0] * 100).sort_values(ascending=False)
    missing_df = pd.concat([n_miss, np.round(ratio, 2)], axis=1, keys=['n_miss', 'ratio'])
    print(missing_df, end="\n")
    if na_name:
        return na_columns

# %%
missing_values_table(df)
# Out:
#         n_miss  ratio
# Salary      59 18.320

# %%
df.dropna(inplace=True)

# %%
# 8. Feature Extraction (Özellik Çıkarımı)

# %%
new_num_cols=[col for col in num_cols if col!="Salary"]

# %%
#Sıfır olanlar üzerinde çarpma bölme yapmak sorun yaratacağı için üzerine çok ufak bir sayı ekliyoruz
df[new_num_cols]=df[new_num_cols]+0.0000000001

# %%
df['NEW_Hits'] = df['Hits'] / df['CHits'] + df['Hits']
df['NEW_RBI'] = df['RBI'] / df['CRBI']
df['NEW_Walks'] = df['Walks'] / df['CWalks']
df['NEW_PutOuts'] = df['PutOuts'] * df['Years']
df["Hits_Success"] = (df["Hits"] / df["AtBat"]) * 100
df["NEW_CRBI*CATBAT"] = df['CRBI'] * df['CAtBat']
df["NEW_RBI"] = df["RBI"] / df["CRBI"]
df["NEW_Chits"] = df["CHits"] / df["Years"]
df["NEW_CHmRun"] = df["CHmRun"] * df["Years"]
df["NEW_CRuns"] = df["CRuns"] / df["Years"]
df["NEW_Chits"] = df["CHits"] * df["Years"]
df["NEW_RW"] = df["RBI"] * df["Walks"]
df["NEW_RBWALK"] = df["RBI"] / df["Walks"]
df["NEW_CH_CB"] = df["CHits"] / df["CAtBat"]
df["NEW_CHm_CAT"] = df["CHmRun"] / df["CAtBat"]
df['NEW_Diff_Atbat'] = df['AtBat'] - (df['CAtBat'] / df['Years'])
df['NEW_Diff_Hits'] = df['Hits'] - (df['CHits'] / df['Years'])
df['NEW_Diff_HmRun'] = df['HmRun'] - (df['CHmRun'] / df['Years'])
df['NEW_Diff_Runs'] = df['Runs'] - (df['CRuns'] / df['Years'])
df['NEW_Diff_RBI'] = df['RBI'] - (df['CRBI'] / df['Years'])
df['NEW_Diff_Walks'] = df['Walks'] - (df['CWalks'] / df['Years'])

# %%
df.head()
# Out:
#     AtBat    Hits  HmRun   Runs    RBI  Walks  Years   CAtBat    CHits  CHmRun   CRuns    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague  NEW_Hits  NEW_RBI  NEW_Walks  NEW_PutOuts  Hits_Success  NEW_CRBI*CATBAT  NEW_Chits  NEW_CHmRun  NEW_CRuns   NEW_RW  NEW_RBWALK  NEW_CH_CB  NEW_CHm_CAT  NEW_Diff_Atbat  NEW_Diff_Hits  NEW_Diff_HmRun  NEW_Diff_Runs  NEW_Diff_RBI  NEW_Diff_Walks
# 1 315.000  81.000  7.000 24.000 38.000 39.000 14.000 3449.000  835.000  69.000 321.000 414.000 375.000      N        W  632.000   43.000  10.000 475.000         N    81.097    0.092      0.104     8848.000        25.714      1427886.000  11690.000     966.000     22.929 1482.000       0.974      0.242        0.020          68.643         21.357           2.071          1.071         8.429          12.214
# 2 479.000 130.000 18.000 66.000 72.000 76.000  3.000 1624.000  457.000  63.000 224.000 266.000 263.000      A        W  648.625   82.000  14.000 480.000         A   130.284    0.271      0.289     1945.875        27.140       431984.000   1371.000     189.000     74.667 5472.000       0.947      0.281        0.039         -62.333        -22.333          -3.000         -8.667       -16.667         -11.667
# 3 496.000 141.000 20.000 65.000 78.000 37.000 11.000 5628.000 1575.000 204.000 828.000 838.000 354.000      N        E  200.000   11.000   3.000 500.000         N   141.090    0.093      0.105     2200.000        28.427      4716264.000  17325.000    2244.000     75.273 2886.000       2.108      0.280        0.036         -15.636         -2.182           1.455        -10.273         1.818           4.818
# 4 321.000  87.000 10.000 39.000 42.000 30.000  2.000  396.000  101.000  12.000  48.000  46.000  33.000      N        E  648.625   40.000   4.000  91.500         N    87.861    0.913      0.909     1297.250        27.103        18216.000    202.000      24.000     24.000 1260.000       1.400      0.255        0.030         123.000         36.500           4.000         15.000        19.000          13.500
# 5 594.000 169.000  4.000 74.000 51.000 35.000 11.000 4408.000 1133.000  19.000 501.000 336.000 194.000      A        W  282.000  404.500  23.000 750.000         A   169.149    0.152      0.180     3102.000        28.451      1481088.000  12463.000     209.000     45.545 1785.000       1.457      0.257        0.004         193.273         66.000           2.273         28.455        20.455          17.364

# %%
# 9. Encoding (Label Encoding, One-Hot Encoding, Rare Encoding)

# %%
def one_hot_encoder(dataframe, categorical_cols, drop_first=False):
    dataframe = pd.get_dummies(dataframe, columns=categorical_cols, drop_first=drop_first)
    return dataframe

# %%
df = one_hot_encoder(df, cat_cols, drop_first=True)

# %%
df.head()
# Out:
#     AtBat    Hits  HmRun   Runs    RBI  Walks  Years   CAtBat    CHits  CHmRun   CRuns    CRBI  CWalks  PutOuts  Assists  Errors  Salary  NEW_Hits  NEW_RBI  NEW_Walks  NEW_PutOuts  Hits_Success  NEW_CRBI*CATBAT  NEW_Chits  NEW_CHmRun  NEW_CRuns   NEW_RW  NEW_RBWALK  NEW_CH_CB  NEW_CHm_CAT  NEW_Diff_Atbat  NEW_Diff_Hits  NEW_Diff_HmRun  NEW_Diff_Runs  NEW_Diff_RBI  NEW_Diff_Walks  League_N  Division_W  NewLeague_N
# 1 315.000  81.000  7.000 24.000 38.000 39.000 14.000 3449.000  835.000  69.000 321.000 414.000 375.000  632.000   43.000  10.000 475.000    81.097    0.092      0.104     8848.000        25.714      1427886.000  11690.000     966.000     22.929 1482.000       0.974      0.242        0.020          68.643         21.357           2.071          1.071         8.429          12.214         1           1            1
# 2 479.000 130.000 18.000 66.000 72.000 76.000  3.000 1624.000  457.000  63.000 224.000 266.000 263.000  648.625   82.000  14.000 480.000   130.284    0.271      0.289     1945.875        27.140       431984.000   1371.000     189.000     74.667 5472.000       0.947      0.281        0.039         -62.333        -22.333          -3.000         -8.667       -16.667         -11.667         0           1            0
# 3 496.000 141.000 20.000 65.000 78.000 37.000 11.000 5628.000 1575.000 204.000 828.000 838.000 354.000  200.000   11.000   3.000 500.000   141.090    0.093      0.105     2200.000        28.427      4716264.000  17325.000    2244.000     75.273 2886.000       2.108      0.280        0.036         -15.636         -2.182           1.455        -10.273         1.818           4.818         1           0            1
# 4 321.000  87.000 10.000 39.000 42.000 30.000  2.000  396.000  101.000  12.000  48.000  46.000  33.000  648.625   40.000   4.000  91.500    87.861    0.913      0.909     1297.250        27.103        18216.000    202.000      24.000     24.000 1260.000       1.400      0.255        0.030         123.000         36.500           4.000         15.000        19.000          13.500         1           0            1
# 5 594.000 169.000  4.000 74.000 51.000 35.000 11.000 4408.000 1133.000  19.000 501.000 336.000 194.000  282.000  404.500  23.000 750.000   169.149    0.152      0.180     3102.000        28.451      1481088.000  12463.000     209.000     45.545 1785.000       1.457      0.257        0.004         193.273         66.000           2.273         28.455        20.455          17.364         0           1            0

# %%
# 10. Feature Scaling (Özellik Ölçeklendirme)

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 263
# Variables: 39
# cat_cols: 3
# num_cols: 36
# cat_but_car: 0
# num_but_cat: 3

# %%
num_cols = [col for col in num_cols if col not in ["Salary"]]

# %%
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df.head()
# Out:
#    AtBat   Hits  HmRun   Runs    RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns   CRBI  CWalks  PutOuts  Assists  Errors  Salary  NEW_Hits  NEW_RBI  NEW_Walks  NEW_PutOuts  Hits_Success  NEW_CRBI*CATBAT  NEW_Chits  NEW_CHmRun  NEW_CRuns  NEW_RW  NEW_RBWALK  NEW_CH_CB  NEW_CHm_CAT  NEW_Diff_Atbat  NEW_Diff_Hits  NEW_Diff_HmRun  NEW_Diff_Runs  NEW_Diff_RBI  NEW_Diff_Walks  League_N  Division_W  NewLeague_N
# 1 -0.603 -0.596 -0.530 -1.207 -0.522 -0.097  1.409   0.373  0.201   0.110 -0.113  0.366   0.592    2.072   -0.528   0.242 475.000    -0.601   -0.836     -0.793        3.327        -0.168            0.011      0.371       0.302     -1.063  -0.466      -0.580     -0.873       -0.273          -0.004          0.093          -0.280         -0.473        -0.213           0.155         1           1            1
# 2  0.513  0.492  0.738  0.442  0.795  1.615 -0.905  -0.461 -0.418   0.012 -0.425 -0.169   0.081    2.163   -0.242   0.877 480.000     0.492   -0.230     -0.149        0.056         0.277           -0.468     -0.617      -0.502      1.419   1.488      -0.613      0.805        1.012          -1.149         -1.229          -1.283         -1.010        -1.676          -1.501         0           1            0
# 3  0.628  0.736  0.969  0.403  1.027 -0.189  0.778   1.369  1.413   2.305  1.518  1.898   0.496   -0.301   -0.762  -0.871 500.000     0.732   -0.831     -0.791        0.176         0.679            1.594      0.910       1.624      1.448   0.221       0.782      0.739        0.838          -0.741         -0.619          -0.402         -1.098        -0.599          -0.358         1           0            1
# 4 -0.562 -0.462 -0.184 -0.618 -0.367 -0.513 -1.115  -1.022 -1.002  -0.817 -0.991 -0.964  -0.969    2.163   -0.550  -0.712  91.500    -0.451    1.943      2.008       -0.252         0.265           -0.668     -0.729      -0.673     -1.011  -0.575      -0.069     -0.320        0.432           0.471          0.551           0.101          0.295         0.403           0.244         1           0            1
# 5  1.295  1.358 -0.876  0.757 -0.019 -0.282  0.778   0.812  0.689  -0.704  0.466  0.084  -0.234    0.150    2.118   2.307 750.000     1.355   -0.633     -0.527        0.604         0.686            0.037      0.445      -0.481      0.022  -0.318      -0.000     -0.235       -1.346           1.086          1.443          -0.240          1.036         0.488           0.512         0           1            0

# %% [markdown]
# # Base Models

# %%
y = df["Salary"]
X = df.drop(["Salary"], axis=1)

models = [('LR', LinearRegression()),
          ("Ridge", Ridge()),
          ("Lasso", Lasso()),
          ("ElasticNet", ElasticNet()),
          ('KNN', KNeighborsRegressor()),
          ('CART', DecisionTreeRegressor()),
          ('RF', RandomForestRegressor()),
          ('SVR', SVR()),
          ('GBM', GradientBoostingRegressor()),
          ("XGBoost", XGBRegressor(objective='reg:squarederror')),
          ("LightGBM", LGBMRegressor()),
          ("CatBoost", CatBoostRegressor(verbose=False))]

# %%
for name, regressor in models:
    rmse = np.mean(np.sqrt(-cross_val_score(regressor, X, y, cv=10, scoring="neg_mean_squared_error")))
    print(f"RMSE: {round(rmse, 4)} ({name}) ")
# Out:
# RMSE: 236.0151 (LR)
# RMSE: 232.0914 (Ridge)
# RMSE: 230.1802 (Lasso)
# RMSE: 256.2534 (ElasticNet)
# RMSE: 253.4936 (KNN)
# RMSE: 294.9323 (CART)
# RMSE: 206.9082 (RF)
# RMSE: 398.3709 (SVR)
# RMSE: 202.6184 (GBM)
# RMSE: 235.3938 (XGBoost)
# RMSE: 228.8917 (LightGBM)
# RMSE: 216.6573 (CatBoost)

# %%
################################################
# Random Forests
################################################

rf_model = RandomForestRegressor(random_state=17)

rf_params = {"max_depth": [5, 8, 15, None],
             "max_features": [5, 7, "auto"],
             "min_samples_split": [8, 15, 20],
             "n_estimators": [200, 500]}

rf_best_grid = GridSearchCV(rf_model, rf_params, cv=5, n_jobs=-1, verbose=True).fit(X, y)
rf_final = rf_model.set_params(**rf_best_grid.best_params_, random_state=17).fit(X, y)
rmse = np.mean(np.sqrt(-cross_val_score(rf_final, X, y, cv=10, scoring="neg_mean_squared_error")))
rmse
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# 205.76771033496897

# %%
################################################
# GBM Model
################################################

gbm_model = GradientBoostingRegressor(random_state=17)

gbm_params = {"learning_rate": [0.01, 0.1],
              "max_depth": [3, 8],
              "n_estimators": [500, 1000],
              "subsample": [1, 0.5, 0.7]}

gbm_best_grid = GridSearchCV(gbm_model, gbm_params, cv=5, n_jobs=-1, verbose=True).fit(X, y)
gbm_final = gbm_model.set_params(**gbm_best_grid.best_params_, random_state=17, ).fit(X, y)
rmse = np.mean(np.sqrt(-cross_val_score(gbm_final, X, y, cv=10, scoring="neg_mean_squared_error")))
rmse
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# 203.202732974011

# %%
################################################
# LightGBM
################################################

lgbm_model = LGBMRegressor(random_state=17)

lgbm_params = {"learning_rate": [0.01, 0.1],
                "n_estimators": [300, 500],
                "colsample_bytree": [0.7, 1]}

lgbm_best_grid = GridSearchCV(lgbm_model, lgbm_params, cv=5, n_jobs=-1, verbose=True).fit(X, y)
lgbm_final = lgbm_model.set_params(**lgbm_best_grid.best_params_, random_state=17).fit(X, y)
rmse = np.mean(np.sqrt(-cross_val_score(lgbm_final, X, y, cv=10, scoring="neg_mean_squared_error")))
rmse
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# 223.25086589452295

# %%
################################################
# CatBoost
################################################

catboost_model = CatBoostRegressor(random_state=17, verbose=False)

catboost_params = {"iterations": [200, 500],
                   "learning_rate": [0.01, 0.1],
                   "depth": [3, 6]}

catboost_best_grid = GridSearchCV(catboost_model, catboost_params, cv=5, n_jobs=-1, verbose=True).fit(X, y)
catboost_final = catboost_model.set_params(**catboost_best_grid.best_params_, random_state=17).fit(X, y)
rmse = np.mean(np.sqrt(-cross_val_score(catboost_final, X, y, cv=10, scoring="neg_mean_squared_error")))
rmse
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# 210.40896582670925

# %%
######################################################
#  Automated Hyperparameter Optimization
######################################################

rf_params = {"max_depth": [5, 8, 15, None],
             "max_features": [5, 7, "auto"],
             "min_samples_split": [8, 15, 20],
             "n_estimators": [200, 500]}

gbm_params = {"learning_rate": [0.01, 0.1],
              "max_depth": [3, 8],
              "n_estimators": [500, 1000],
              "subsample": [1, 0.5, 0.7]}


lightgbm_params = {"learning_rate": [0.01, 0.1],
                   "n_estimators": [300, 500],
                   "colsample_bytree": [0.7, 1]}

catboost_params = {"iterations": [200, 500],
                   "learning_rate": [0.01, 0.1],
                   "depth": [3, 6]}


regressors = [("RF", RandomForestRegressor(), rf_params),
              ('GBM', GradientBoostingRegressor(), gbm_params),
              ('LightGBM', LGBMRegressor(), lightgbm_params),
              ("CatBoost", CatBoostRegressor(), catboost_params)]


best_models = {}

for name, regressor, params in regressors:
    print(f"########## {name} ##########")
    rmse = np.mean(np.sqrt(-cross_val_score(regressor, X, y, cv=10, scoring="neg_mean_squared_error")))
    print(f"RMSE: {round(rmse, 4)} ({name}) ")

    gs_best = GridSearchCV(regressor, params, cv=3, n_jobs=-1, verbose=False).fit(X, y)

    final_model = regressor.set_params(**gs_best.best_params_)
    rmse = np.mean(np.sqrt(-cross_val_score(final_model, X, y, cv=10, scoring="neg_mean_squared_error")))
    print(f"RMSE (After): {round(rmse, 4)} ({name}) ")

    print(f"{name} best params: {gs_best.best_params_}", end="\n\n")

    best_models[name] = final_model
# Out:
# ########## RF ##########
# RMSE: 205.4137 (RF)
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /Users/mericgenc/opt/anaconda3/envs/genc_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# RMSE (After): 203.4377 (RF)
# RF best params: {'max_depth': None, 'max_features': 'auto', 'min_samples_split': 8, 'n_estimators': 200}
#
# ########## GBM ##########
# RMSE: 199.8295 (GBM)
# RMSE (After): 202.656 (GBM)
# GBM best params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.7}
#
# ########## LightGBM ##########
# RMSE: 228.8917 (LightGBM)
# RMSE (After): 223.4899 (LightGBM)
# LightGBM best params: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'n_estimators': 500}
#
# ########## CatBoost ##########
# Learning rate set to 0.032591
# 0:	learn: 403.3340596	total: 3.36ms	remaining: 3.35s
# 1:	learn: 397.0460523	total: 5.31ms	remaining: 2.65s
# 2:	learn: 390.8226218	total: 7.08ms	remaining: 2.35s
# 3:	learn: 384.5883790	total: 8.71ms	remaining: 2.17s
# 4:	learn: 378.6544455	total: 11.5ms	remaining: 2.29s
# 5:	learn: 372.5626807	total: 13.9ms	remaining: 2.31s
# 6:	learn: 366.3399869	total: 15.7ms	remaining: 2.22s
# 7:	learn: 360.5902593	total: 17.6ms	remaining: 2.19s
# 8:	learn: 355.2793833	total: 19.3ms	remaining: 2.12s
# 9:	learn: 349.8434345	total: 21.2ms	remaining: 2.1s
# 10:	learn: 345.4037124	total: 22.8ms	remaining: 2.05s
# 11:	learn: 340.7879422	total: 24.5ms	remaining: 2.01s
# 12:	learn: 336.1259848	total: 26.1ms	remaining: 1.98s
# 13:	learn: 331.1630357	total: 27.9ms	remaining: 1.97s
# 14:	learn: 326.2436212	total: 29.7ms	remaining: 1.95s
# 15:	learn: 322.1460542	total: 31.3ms	remaining: 1.93s
# 16:	learn: 317.5360770	total: 32.9ms	remaining: 1.9s
# 17:	learn: 313.8951056	total: 34.8ms	remaining: 1.9s
# 18:	learn: 309.8293036	total: 36.5ms	remaining: 1.89s
# 19:	learn: 306.1741108	total: 38.2ms	remaining: 1.87s
# 20:	learn: 301.7304983	total: 39.9ms	remaining: 1.86s
# 21:	learn: 297.9046805	total: 41.8ms	remaining: 1.86s
# 22:	learn: 293.6694111	total: 43.4ms	remaining: 1.84s
# 23:	learn: 289.9546230	total: 45.9ms	remaining: 1.86s
# 24:	learn: 286.7964949	total: 47.6ms	remaining: 1.86s
# 25:	learn: 283.8225324	total: 49.4ms	remaining: 1.85s
# 26:	learn: 280.0198314	total: 51ms	remaining: 1.84s
# 27:	learn: 276.6927427	total: 52.8ms	remaining: 1.83s
# 28:	learn: 273.9899068	total: 54.8ms	remaining: 1.83s
# 29:	learn: 270.7043595	total: 56.7ms	remaining: 1.83s
# 30:	learn: 267.7346120	total: 58.7ms	remaining: 1.83s
# 31:	learn: 264.3938689	total: 61.4ms	remaining: 1.86s
# 32:	learn: 261.5744748	total: 63.3ms	remaining: 1.85s
# 33:	learn: 258.6990716	total: 65ms	remaining: 1.85s
# 34:	learn: 255.7771623	total: 66.7ms	remaining: 1.84s
# 35:	learn: 252.8964625	total: 68.4ms	remaining: 1.83s
# 36:	learn: 250.3807530	total: 69.9ms	remaining: 1.82s
# 37:	learn: 247.7883093	total: 71.5ms	remaining: 1.81s
# 38:	learn: 245.4239792	total: 73.5ms	remaining: 1.81s
# 39:	learn: 242.8156034	total: 75.5ms	remaining: 1.81s
# 40:	learn: 240.5702674	total: 77.1ms	remaining: 1.8s
# 41:	learn: 237.8380765	total: 79.8ms	remaining: 1.82s
# 42:	learn: 235.3875220	total: 81.5ms	remaining: 1.81s
# 43:	learn: 233.4887363	total: 83.2ms	remaining: 1.81s
# 44:	learn: 231.6002057	total: 84.8ms	remaining: 1.8s
# 45:	learn: 229.4090292	total: 86.6ms	remaining: 1.8s
# 46:	learn: 227.0484001	total: 88.3ms	remaining: 1.79s
# 47:	learn: 225.0545863	total: 89.9ms	remaining: 1.78s
# 48:	learn: 222.9408065	total: 92.7ms	remaining: 1.8s
# 49:	learn: 220.9895548	total: 96.4ms	remaining: 1.83s
# 50:	learn: 219.0165573	total: 99.3ms	remaining: 1.85s
# 51:	learn: 216.8742308	total: 101ms	remaining: 1.84s
# 52:	learn: 215.1643229	total: 103ms	remaining: 1.84s
# 53:	learn: 213.3253741	total: 105ms	remaining: 1.83s
# 54:	learn: 211.8374010	total: 106ms	remaining: 1.83s
# 55:	learn: 209.6310055	total: 108ms	remaining: 1.82s
# 56:	learn: 208.0539008	total: 110ms	remaining: 1.81s
# 57:	learn: 206.1427442	total: 111ms	remaining: 1.81s
# 58:	learn: 204.5316721	total: 113ms	remaining: 1.81s
# 59:	learn: 202.7391315	total: 115ms	remaining: 1.8s
# 60:	learn: 201.1425944	total: 117ms	remaining: 1.8s
# 61:	learn: 199.9361307	total: 119ms	remaining: 1.8s
# 62:	learn: 198.3990775	total: 121ms	remaining: 1.8s
# 63:	learn: 196.9429383	total: 124ms	remaining: 1.81s
# 64:	learn: 195.4380958	total: 126ms	remaining: 1.81s
# 65:	learn: 194.0755899	total: 128ms	remaining: 1.81s
# 66:	learn: 192.5508482	total: 129ms	remaining: 1.8s
# 67:	learn: 191.2770648	total: 131ms	remaining: 1.8s
# 68:	learn: 190.1051060	total: 133ms	remaining: 1.8s
# 69:	learn: 188.9647782	total: 135ms	remaining: 1.8s
# 70:	learn: 187.8580715	total: 137ms	remaining: 1.8s
# 71:	learn: 186.5052736	total: 141ms	remaining: 1.81s
# 72:	learn: 184.9637944	total: 143ms	remaining: 1.81s
# 73:	learn: 183.5315490	total: 145ms	remaining: 1.81s
# 74:	learn: 182.3967613	total: 147ms	remaining: 1.81s
# 75:	learn: 181.2763763	total: 149ms	remaining: 1.81s
# 76:	learn: 180.1635664	total: 151ms	remaining: 1.81s
# 77:	learn: 178.9612023	total: 153ms	remaining: 1.81s
# 78:	learn: 178.0099656	total: 155ms	remaining: 1.8s
# 79:	learn: 177.0143961	total: 158ms	remaining: 1.81s
# 80:	learn: 175.8372404	total: 162ms	remaining: 1.84s
# 81:	learn: 174.6922526	total: 165ms	remaining: 1.84s
# 82:	learn: 173.5419064	total: 166ms	remaining: 1.84s
# 83:	learn: 172.6111772	total: 169ms	remaining: 1.84s
# 84:	learn: 171.8754192	total: 171ms	remaining: 1.83s
# 85:	learn: 170.9257470	total: 172ms	remaining: 1.83s
# 86:	learn: 169.9395422	total: 174ms	remaining: 1.83s
# 87:	learn: 169.2281313	total: 176ms	remaining: 1.83s
# 88:	learn: 168.0847140	total: 178ms	remaining: 1.82s
# 89:	learn: 167.2365065	total: 180ms	remaining: 1.82s
# 90:	learn: 166.4253725	total: 182ms	remaining: 1.81s
# 91:	learn: 165.3927332	total: 184ms	remaining: 1.81s
# 92:	learn: 164.5374309	total: 187ms	remaining: 1.83s
# 93:	learn: 163.7099085	total: 190ms	remaining: 1.83s
# 94:	learn: 162.8841888	total: 192ms	remaining: 1.83s
# 95:	learn: 161.9033810	total: 194ms	remaining: 1.82s
# 96:	learn: 160.9970077	total: 196ms	remaining: 1.82s
# 97:	learn: 160.3329020	total: 197ms	remaining: 1.82s
# 98:	learn: 159.6776582	total: 200ms	remaining: 1.81s
# 99:	learn: 159.2007881	total: 202ms	remaining: 1.82s
# 100:	learn: 158.6297743	total: 208ms	remaining: 1.85s
# 101:	learn: 158.0815453	total: 210ms	remaining: 1.84s
# 102:	learn: 157.4406604	total: 211ms	remaining: 1.84s
# 103:	learn: 156.9138824	total: 213ms	remaining: 1.84s
# 104:	learn: 156.5747667	total: 215ms	remaining: 1.83s
# 105:	learn: 155.6963730	total: 216ms	remaining: 1.82s
# 106:	learn: 154.7540045	total: 218ms	remaining: 1.82s
# 107:	learn: 153.9768645	total: 220ms	remaining: 1.82s
# 108:	learn: 153.1831953	total: 222ms	remaining: 1.82s
# 109:	learn: 152.3094765	total: 224ms	remaining: 1.81s
# 110:	learn: 151.5196516	total: 226ms	remaining: 1.81s
# 111:	learn: 150.9144579	total: 228ms	remaining: 1.8s
# 112:	learn: 150.5297643	total: 229ms	remaining: 1.8s
# 113:	learn: 149.8070311	total: 231ms	remaining: 1.8s
# 114:	learn: 149.4309581	total: 234ms	remaining: 1.8s
# 115:	learn: 148.8487901	total: 236ms	remaining: 1.79s
# 116:	learn: 148.2416517	total: 240ms	remaining: 1.81s
# 117:	learn: 147.4472454	total: 242ms	remaining: 1.8s
# 118:	learn: 146.9928235	total: 243ms	remaining: 1.8s
# 119:	learn: 146.5773907	total: 245ms	remaining: 1.8s
# 120:	learn: 146.0436252	total: 247ms	remaining: 1.79s
# 121:	learn: 145.0143747	total: 248ms	remaining: 1.78s
# 122:	learn: 144.3927173	total: 250ms	remaining: 1.78s
# 123:	learn: 143.8757268	total: 252ms	remaining: 1.78s
# 124:	learn: 143.4334091	total: 254ms	remaining: 1.78s
# 125:	learn: 142.9997165	total: 256ms	remaining: 1.78s
# 126:	learn: 142.5133951	total: 258ms	remaining: 1.77s
# 127:	learn: 141.9447729	total: 260ms	remaining: 1.77s
# 128:	learn: 141.3523516	total: 261ms	remaining: 1.76s
# 129:	learn: 140.4661392	total: 263ms	remaining: 1.76s
# 130:	learn: 140.0538628	total: 265ms	remaining: 1.75s
# 131:	learn: 139.6193438	total: 266ms	remaining: 1.75s
# 132:	learn: 139.1304228	total: 268ms	remaining: 1.75s
# 133:	learn: 138.9070173	total: 270ms	remaining: 1.74s
# 134:	learn: 138.3211780	total: 271ms	remaining: 1.74s
# 135:	learn: 137.8629188	total: 273ms	remaining: 1.73s
# 136:	learn: 137.3768630	total: 274ms	remaining: 1.73s
# 137:	learn: 136.8671818	total: 276ms	remaining: 1.72s
# 138:	learn: 136.5328532	total: 278ms	remaining: 1.72s
# 139:	learn: 135.7733493	total: 279ms	remaining: 1.71s
# 140:	learn: 135.4654672	total: 281ms	remaining: 1.71s
# 141:	learn: 134.9546538	total: 282ms	remaining: 1.71s
# 142:	learn: 134.6637996	total: 284ms	remaining: 1.7s
# 143:	learn: 134.0156575	total: 287ms	remaining: 1.7s
# 144:	learn: 133.6121831	total: 288ms	remaining: 1.7s
# 145:	learn: 133.0625198	total: 290ms	remaining: 1.7s
# 146:	learn: 132.7075712	total: 291ms	remaining: 1.69s
# 147:	learn: 132.2187173	total: 293ms	remaining: 1.69s
# 148:	learn: 131.6741797	total: 295ms	remaining: 1.68s
# 149:	learn: 131.1698676	total: 297ms	remaining: 1.68s
# 150:	learn: 130.7663661	total: 299ms	remaining: 1.68s
# 151:	learn: 130.1608348	total: 302ms	remaining: 1.68s
# 152:	learn: 129.5337475	total: 303ms	remaining: 1.68s
# 153:	learn: 128.9111996	total: 305ms	remaining: 1.68s
# 154:	learn: 128.6977286	total: 308ms	remaining: 1.68s
# 155:	learn: 128.5546132	total: 311ms	remaining: 1.68s
# 156:	learn: 128.0627575	total: 313ms	remaining: 1.68s
# 157:	learn: 127.7701934	total: 315ms	remaining: 1.68s
# 158:	learn: 127.4946784	total: 318ms	remaining: 1.68s
# 159:	learn: 127.1388179	total: 319ms	remaining: 1.68s
# 160:	learn: 126.8793877	total: 321ms	remaining: 1.67s
# 161:	learn: 126.6622105	total: 324ms	remaining: 1.67s
# 162:	learn: 126.3240513	total: 325ms	remaining: 1.67s
# 163:	learn: 125.9574318	total: 327ms	remaining: 1.66s
# 164:	learn: 125.6351744	total: 328ms	remaining: 1.66s
# 165:	learn: 125.4422240	total: 330ms	remaining: 1.66s
# 166:	learn: 125.2589763	total: 332ms	remaining: 1.65s
# 167:	learn: 124.7780508	total: 334ms	remaining: 1.65s
# 168:	learn: 124.2247520	total: 335ms	remaining: 1.65s
# 169:	learn: 123.6100811	total: 337ms	remaining: 1.65s
# 170:	learn: 123.1112961	total: 339ms	remaining: 1.64s
# 171:	learn: 122.6825994	total: 340ms	remaining: 1.64s
# 172:	learn: 122.4172709	total: 342ms	remaining: 1.63s
# 173:	learn: 122.1497796	total: 343ms	remaining: 1.63s
# 174:	learn: 121.7178917	total: 345ms	remaining: 1.63s
# 175:	learn: 121.1315466	total: 347ms	remaining: 1.62s
# 176:	learn: 120.9133567	total: 348ms	remaining: 1.62s
# 177:	learn: 120.7296945	total: 350ms	remaining: 1.62s
# 178:	learn: 120.2562632	total: 352ms	remaining: 1.61s
# 179:	learn: 120.0224097	total: 355ms	remaining: 1.61s
# 180:	learn: 119.8608213	total: 356ms	remaining: 1.61s
# 181:	learn: 119.5338215	total: 358ms	remaining: 1.61s
# 182:	learn: 118.9829216	total: 359ms	remaining: 1.6s
# 183:	learn: 118.4679533	total: 361ms	remaining: 1.6s
# 184:	learn: 118.1611192	total: 363ms	remaining: 1.6s
# 185:	learn: 117.9668411	total: 365ms	remaining: 1.6s
# 186:	learn: 117.6855382	total: 367ms	remaining: 1.59s
# 187:	learn: 117.3632450	total: 369ms	remaining: 1.59s
# 188:	learn: 116.9048822	total: 371ms	remaining: 1.59s
# 189:	learn: 116.4944454	total: 372ms	remaining: 1.59s
# 190:	learn: 115.8402716	total: 374ms	remaining: 1.58s
# 191:	learn: 115.6019456	total: 375ms	remaining: 1.58s
# 192:	learn: 115.3853404	total: 377ms	remaining: 1.58s
# 193:	learn: 115.2062120	total: 379ms	remaining: 1.57s
# 194:	learn: 114.6941202	total: 383ms	remaining: 1.58s
# 195:	learn: 114.3632075	total: 385ms	remaining: 1.58s
# 196:	learn: 114.0140764	total: 387ms	remaining: 1.58s
# 197:	learn: 113.8686434	total: 388ms	remaining: 1.57s
# 198:	learn: 113.6486639	total: 390ms	remaining: 1.57s
# 199:	learn: 113.0507384	total: 391ms	remaining: 1.56s
# 200:	learn: 112.4917584	total: 394ms	remaining: 1.56s
# 201:	learn: 112.1992564	total: 396ms	remaining: 1.56s
# 202:	learn: 111.7956144	total: 398ms	remaining: 1.56s
# 203:	learn: 111.6234738	total: 400ms	remaining: 1.56s
# 204:	learn: 111.1657311	total: 402ms	remaining: 1.56s
# 205:	learn: 110.6558015	total: 404ms	remaining: 1.56s
# 206:	learn: 110.2063463	total: 406ms	remaining: 1.55s
# 207:	learn: 110.1016589	total: 407ms	remaining: 1.55s
# 208:	learn: 109.4680675	total: 409ms	remaining: 1.55s
# 209:	learn: 109.3413267	total: 411ms	remaining: 1.54s
# 210:	learn: 109.2227593	total: 412ms	remaining: 1.54s
# 211:	learn: 109.0123671	total: 414ms	remaining: 1.54s
# 212:	learn: 108.8605904	total: 415ms	remaining: 1.53s
# 213:	learn: 108.3540390	total: 417ms	remaining: 1.53s
# 214:	learn: 107.8518415	total: 419ms	remaining: 1.53s
# 215:	learn: 107.6135897	total: 421ms	remaining: 1.53s
# 216:	learn: 107.3221819	total: 422ms	remaining: 1.52s
# 217:	learn: 106.7100832	total: 424ms	remaining: 1.52s
# 218:	learn: 106.1155026	total: 426ms	remaining: 1.52s
# 219:	learn: 105.7285182	total: 429ms	remaining: 1.52s
# 220:	learn: 105.3885772	total: 431ms	remaining: 1.52s
# 221:	learn: 104.7901582	total: 434ms	remaining: 1.52s
# 222:	learn: 104.2816781	total: 435ms	remaining: 1.52s
# 223:	learn: 103.7281893	total: 437ms	remaining: 1.51s
# 224:	learn: 103.0985050	total: 439ms	remaining: 1.51s
# 225:	learn: 102.9045611	total: 440ms	remaining: 1.51s
# 226:	learn: 102.4448199	total: 442ms	remaining: 1.5s
# 227:	learn: 102.2504689	total: 446ms	remaining: 1.51s
# 228:	learn: 101.7418209	total: 448ms	remaining: 1.51s
# 229:	learn: 101.4762010	total: 450ms	remaining: 1.5s
# 230:	learn: 101.2763352	total: 451ms	remaining: 1.5s
# 231:	learn: 100.6079832	total: 453ms	remaining: 1.5s
# 232:	learn: 100.2050195	total: 455ms	remaining: 1.5s
# 233:	learn: 99.5789840	total: 456ms	remaining: 1.49s
# 234:	learn: 99.4331631	total: 458ms	remaining: 1.49s
# 235:	learn: 99.0156675	total: 459ms	remaining: 1.49s
# 236:	learn: 98.7461370	total: 461ms	remaining: 1.48s
# 237:	learn: 98.5449053	total: 463ms	remaining: 1.48s
# 238:	learn: 98.1074718	total: 464ms	remaining: 1.48s
# 239:	learn: 97.6873315	total: 466ms	remaining: 1.48s
# 240:	learn: 97.2912828	total: 468ms	remaining: 1.47s
# 241:	learn: 96.8975552	total: 469ms	remaining: 1.47s
# 242:	learn: 96.7804057	total: 471ms	remaining: 1.47s
# 243:	learn: 96.1569259	total: 473ms	remaining: 1.46s
# 244:	learn: 95.6833513	total: 474ms	remaining: 1.46s
# 245:	learn: 95.3460287	total: 477ms	remaining: 1.46s
# 246:	learn: 94.7058688	total: 478ms	remaining: 1.46s
# 247:	learn: 94.3323054	total: 480ms	remaining: 1.46s
# 248:	learn: 93.9473235	total: 482ms	remaining: 1.45s
# 249:	learn: 93.8540361	total: 483ms	remaining: 1.45s
# 250:	learn: 93.2782198	total: 485ms	remaining: 1.45s
# 251:	learn: 93.0977954	total: 487ms	remaining: 1.44s
# 252:	learn: 92.8345847	total: 489ms	remaining: 1.44s
# 253:	learn: 92.6959710	total: 493ms	remaining: 1.45s
# 254:	learn: 92.2501907	total: 495ms	remaining: 1.45s
# 255:	learn: 91.8784553	total: 498ms	remaining: 1.45s
# 256:	learn: 91.7191453	total: 499ms	remaining: 1.44s
# 257:	learn: 91.5279186	total: 501ms	remaining: 1.44s
# 258:	learn: 91.3756516	total: 502ms	remaining: 1.44s
# 259:	learn: 91.0139212	total: 504ms	remaining: 1.43s
# 260:	learn: 90.6562377	total: 506ms	remaining: 1.43s
# 261:	learn: 90.5688437	total: 508ms	remaining: 1.43s
# 262:	learn: 90.2294154	total: 510ms	remaining: 1.43s
# 263:	learn: 90.0801200	total: 512ms	remaining: 1.43s
# 264:	learn: 89.8861454	total: 514ms	remaining: 1.42s
# 265:	learn: 89.4947369	total: 515ms	remaining: 1.42s
# 266:	learn: 88.9613035	total: 517ms	remaining: 1.42s
# 267:	learn: 88.4662782	total: 518ms	remaining: 1.42s
# 268:	learn: 88.2258569	total: 520ms	remaining: 1.41s
# 269:	learn: 87.7016435	total: 521ms	remaining: 1.41s
# 270:	learn: 87.6202158	total: 525ms	remaining: 1.41s
# 271:	learn: 87.2787658	total: 528ms	remaining: 1.41s
# 272:	learn: 86.9535751	total: 529ms	remaining: 1.41s
# 273:	learn: 86.7489377	total: 531ms	remaining: 1.41s
# 274:	learn: 86.3890358	total: 533ms	remaining: 1.4s
# 275:	learn: 85.9466247	total: 534ms	remaining: 1.4s
# 276:	learn: 85.5742488	total: 535ms	remaining: 1.4s
# 277:	learn: 85.0431366	total: 537ms	remaining: 1.39s
# 278:	learn: 84.7699255	total: 539ms	remaining: 1.39s
# 279:	learn: 84.5990657	total: 540ms	remaining: 1.39s
# 280:	learn: 84.2491183	total: 543ms	remaining: 1.39s
# 281:	learn: 83.6736725	total: 547ms	remaining: 1.39s
# 282:	learn: 83.2159697	total: 549ms	remaining: 1.39s
# 283:	learn: 82.9464601	total: 551ms	remaining: 1.39s
# 284:	learn: 82.5698479	total: 552ms	remaining: 1.39s
# 285:	learn: 82.4408852	total: 555ms	remaining: 1.39s
# 286:	learn: 82.1167125	total: 557ms	remaining: 1.38s
# 287:	learn: 81.7968527	total: 560ms	remaining: 1.38s
# 288:	learn: 81.4635183	total: 561ms	remaining: 1.38s
# 289:	learn: 81.3377397	total: 563ms	remaining: 1.38s
# 290:	learn: 80.8289239	total: 564ms	remaining: 1.38s
# 291:	learn: 80.4556633	total: 566ms	remaining: 1.37s
# 292:	learn: 79.9513713	total: 568ms	remaining: 1.37s
# 293:	learn: 79.5417327	total: 569ms	remaining: 1.37s
# 294:	learn: 79.2690071	total: 571ms	remaining: 1.36s
# 295:	learn: 78.8627572	total: 573ms	remaining: 1.36s
# 296:	learn: 78.7171135	total: 575ms	remaining: 1.36s
# 297:	learn: 78.4426965	total: 577ms	remaining: 1.36s
# 298:	learn: 78.3151151	total: 579ms	remaining: 1.36s
# 299:	learn: 78.1825925	total: 581ms	remaining: 1.35s
# 300:	learn: 77.9494423	total: 583ms	remaining: 1.35s
# 301:	learn: 77.7630962	total: 585ms	remaining: 1.35s
# 302:	learn: 77.6521190	total: 586ms	remaining: 1.35s
# 303:	learn: 77.2210762	total: 588ms	remaining: 1.35s
# 304:	learn: 77.1045290	total: 591ms	remaining: 1.35s
# 305:	learn: 76.6772395	total: 593ms	remaining: 1.34s
# 306:	learn: 76.3969052	total: 595ms	remaining: 1.34s
# 307:	learn: 76.1879743	total: 596ms	remaining: 1.34s
# 308:	learn: 76.0732868	total: 598ms	remaining: 1.34s
# 309:	learn: 75.8280784	total: 599ms	remaining: 1.33s
# 310:	learn: 75.3294391	total: 602ms	remaining: 1.33s
# 311:	learn: 75.1623491	total: 605ms	remaining: 1.33s
# 312:	learn: 74.7173676	total: 607ms	remaining: 1.33s
# 313:	learn: 74.5859822	total: 608ms	remaining: 1.33s
# 314:	learn: 74.3164349	total: 610ms	remaining: 1.33s
# 315:	learn: 74.1913770	total: 612ms	remaining: 1.32s
# 316:	learn: 74.0116967	total: 613ms	remaining: 1.32s
# 317:	learn: 73.9093004	total: 615ms	remaining: 1.32s
# 318:	learn: 73.7165849	total: 619ms	remaining: 1.32s
# 319:	learn: 73.6101039	total: 621ms	remaining: 1.32s
# 320:	learn: 73.3736263	total: 623ms	remaining: 1.32s
# 321:	learn: 73.2966628	total: 624ms	remaining: 1.31s
# 322:	learn: 73.0337640	total: 626ms	remaining: 1.31s
# 323:	learn: 72.9501160	total: 627ms	remaining: 1.31s
# 324:	learn: 72.7370933	total: 629ms	remaining: 1.31s
# 325:	learn: 72.5647431	total: 642ms	remaining: 1.33s
# 326:	learn: 72.3574478	total: 643ms	remaining: 1.32s
# 327:	learn: 72.0350670	total: 645ms	remaining: 1.32s
# 328:	learn: 71.9644955	total: 646ms	remaining: 1.32s
# 329:	learn: 71.8031064	total: 649ms	remaining: 1.32s
# 330:	learn: 71.6454661	total: 650ms	remaining: 1.31s
# 331:	learn: 71.4831183	total: 652ms	remaining: 1.31s
# 332:	learn: 71.3169967	total: 653ms	remaining: 1.31s
# 333:	learn: 71.0744345	total: 655ms	remaining: 1.31s
# 334:	learn: 70.9423463	total: 657ms	remaining: 1.3s
# 335:	learn: 70.8662588	total: 659ms	remaining: 1.3s
# 336:	learn: 70.5558396	total: 661ms	remaining: 1.3s
# 337:	learn: 70.1432567	total: 662ms	remaining: 1.3s
# 338:	learn: 69.8926381	total: 664ms	remaining: 1.29s
# 339:	learn: 69.5850298	total: 666ms	remaining: 1.29s
# 340:	learn: 69.4748768	total: 667ms	remaining: 1.29s
# 341:	learn: 69.2224817	total: 669ms	remaining: 1.29s
# 342:	learn: 69.1077867	total: 670ms	remaining: 1.28s
# 343:	learn: 68.8994546	total: 672ms	remaining: 1.28s
# 344:	learn: 68.6812317	total: 674ms	remaining: 1.28s
# 345:	learn: 68.5727282	total: 676ms	remaining: 1.28s
# 346:	learn: 68.5227385	total: 677ms	remaining: 1.27s
# 347:	learn: 68.4578414	total: 679ms	remaining: 1.27s
# 348:	learn: 68.1991800	total: 681ms	remaining: 1.27s
# 349:	learn: 68.0755817	total: 682ms	remaining: 1.27s
# 350:	learn: 67.8478679	total: 684ms	remaining: 1.26s
# 351:	learn: 67.4118379	total: 685ms	remaining: 1.26s
# 352:	learn: 67.0600095	total: 687ms	remaining: 1.26s
# 353:	learn: 66.7615006	total: 689ms	remaining: 1.26s
# 354:	learn: 66.6006989	total: 690ms	remaining: 1.25s
# 355:	learn: 66.3296474	total: 692ms	remaining: 1.25s
# 356:	learn: 66.1753985	total: 694ms	remaining: 1.25s
# 357:	learn: 65.9599696	total: 696ms	remaining: 1.25s
# 358:	learn: 65.5631834	total: 697ms	remaining: 1.24s
# 359:	learn: 65.4695814	total: 699ms	remaining: 1.24s
# 360:	learn: 65.2250792	total: 700ms	remaining: 1.24s
# 361:	learn: 64.9673904	total: 702ms	remaining: 1.24s
# 362:	learn: 64.7626552	total: 704ms	remaining: 1.24s
# 363:	learn: 64.4677072	total: 705ms	remaining: 1.23s
# 364:	learn: 64.3655406	total: 707ms	remaining: 1.23s
# 365:	learn: 64.1032937	total: 709ms	remaining: 1.23s
# 366:	learn: 63.9130621	total: 710ms	remaining: 1.22s
# 367:	learn: 63.7514148	total: 712ms	remaining: 1.22s
# 368:	learn: 63.6495560	total: 713ms	remaining: 1.22s
# 369:	learn: 63.4928168	total: 715ms	remaining: 1.22s
# 370:	learn: 63.2086470	total: 719ms	remaining: 1.22s
# 371:	learn: 62.9647496	total: 720ms	remaining: 1.22s
# 372:	learn: 62.5471231	total: 722ms	remaining: 1.21s
# 373:	learn: 62.4872282	total: 724ms	remaining: 1.21s
# 374:	learn: 62.1966709	total: 732ms	remaining: 1.22s
# 375:	learn: 62.0951925	total: 733ms	remaining: 1.22s
# 376:	learn: 61.8395716	total: 735ms	remaining: 1.21s
# 377:	learn: 61.7305258	total: 736ms	remaining: 1.21s
# ...
# 198:	learn: 31.7209775	total: 391ms	remaining: 592ms
# 199:	learn: 31.6927650	total: 393ms	remaining: 589ms
# 200:	learn: 31.6176060	total: 394ms	remaining: 586ms
# 201:	learn: 31.5849007	total: 396ms	remaining: 584ms
# 202:	learn: 31.5116295	total: 397ms	remaining: 581ms
# 203:	learn: 31.1877338	total: 399ms	remaining: 579ms
# 204:	learn: 30.8230626	total: 401ms	remaining: 577ms
# 205:	learn: 30.5825323	total: 403ms	remaining: 575ms
# 206:	learn: 30.3830227	total: 405ms	remaining: 573ms
# 207:	learn: 29.9690689	total: 406ms	remaining: 570ms
# 208:	learn: 29.8957197	total: 409ms	remaining: 569ms
# 209:	learn: 29.7908220	total: 410ms	remaining: 566ms
# 210:	learn: 29.7536154	total: 412ms	remaining: 564ms
# 211:	learn: 29.5835780	total: 414ms	remaining: 562ms
# 212:	learn: 29.5673883	total: 415ms	remaining: 560ms
# 213:	learn: 29.2097854	total: 417ms	remaining: 557ms
# 214:	learn: 28.9237670	total: 419ms	remaining: 555ms
# 215:	learn: 28.7592250	total: 422ms	remaining: 554ms
# 216:	learn: 28.6796425	total: 425ms	remaining: 554ms
# 217:	learn: 28.4163677	total: 426ms	remaining: 551ms
# 218:	learn: 28.1862728	total: 428ms	remaining: 549ms
# 219:	learn: 27.9122272	total: 430ms	remaining: 547ms
# 220:	learn: 27.7372588	total: 431ms	remaining: 544ms
# 221:	learn: 27.4137361	total: 433ms	remaining: 542ms
# 222:	learn: 27.2428361	total: 435ms	remaining: 540ms
# 223:	learn: 27.0819108	total: 436ms	remaining: 537ms
# 224:	learn: 26.7908734	total: 438ms	remaining: 535ms
# 225:	learn: 26.3369877	total: 440ms	remaining: 533ms
# 226:	learn: 26.1658404	total: 442ms	remaining: 531ms
# 227:	learn: 26.0018452	total: 443ms	remaining: 529ms
# 228:	learn: 25.6193483	total: 445ms	remaining: 526ms
# 229:	learn: 25.3408905	total: 447ms	remaining: 524ms
# 230:	learn: 25.0934584	total: 449ms	remaining: 522ms
# 231:	learn: 24.9384041	total: 451ms	remaining: 520ms
# 232:	learn: 24.7782234	total: 452ms	remaining: 518ms
# 233:	learn: 24.4645225	total: 454ms	remaining: 516ms
# 234:	learn: 24.0733038	total: 456ms	remaining: 514ms
# 235:	learn: 24.0408143	total: 457ms	remaining: 511ms
# 236:	learn: 24.0234329	total: 459ms	remaining: 509ms
# 237:	learn: 23.9580414	total: 460ms	remaining: 507ms
# 238:	learn: 23.9272106	total: 462ms	remaining: 504ms
# 239:	learn: 23.5926162	total: 463ms	remaining: 502ms
# 240:	learn: 23.5212856	total: 465ms	remaining: 500ms
# 241:	learn: 23.3368427	total: 467ms	remaining: 498ms
# 242:	learn: 23.1602953	total: 468ms	remaining: 495ms
# 243:	learn: 22.6529354	total: 470ms	remaining: 493ms
# 244:	learn: 22.5579453	total: 471ms	remaining: 491ms
# 245:	learn: 22.2452115	total: 473ms	remaining: 488ms
# 246:	learn: 21.9831643	total: 475ms	remaining: 486ms
# 247:	learn: 21.7112999	total: 476ms	remaining: 484ms
# 248:	learn: 21.4745765	total: 478ms	remaining: 482ms
# 249:	learn: 21.2943062	total: 479ms	remaining: 479ms
# 250:	learn: 21.2219067	total: 481ms	remaining: 477ms
# 251:	learn: 20.9620908	total: 482ms	remaining: 475ms
# 252:	learn: 20.5456701	total: 484ms	remaining: 473ms
# 253:	learn: 20.3430860	total: 486ms	remaining: 470ms
# 254:	learn: 20.2283341	total: 488ms	remaining: 468ms
# 255:	learn: 20.0129701	total: 489ms	remaining: 466ms
# 256:	learn: 19.9961318	total: 491ms	remaining: 464ms
# 257:	learn: 19.9219983	total: 492ms	remaining: 462ms
# 258:	learn: 19.8875979	total: 494ms	remaining: 460ms
# 259:	learn: 19.6742894	total: 496ms	remaining: 458ms
# 260:	learn: 19.5788358	total: 498ms	remaining: 456ms
# 261:	learn: 19.4215264	total: 499ms	remaining: 454ms
# 262:	learn: 19.3567913	total: 501ms	remaining: 452ms
# 263:	learn: 19.3173688	total: 503ms	remaining: 450ms
# 264:	learn: 19.0770957	total: 504ms	remaining: 447ms
# 265:	learn: 18.8902418	total: 506ms	remaining: 445ms
# 266:	learn: 18.5650889	total: 508ms	remaining: 443ms
# 267:	learn: 18.3464725	total: 509ms	remaining: 441ms
# 268:	learn: 18.2384012	total: 512ms	remaining: 439ms
# 269:	learn: 18.0787542	total: 513ms	remaining: 437ms
# 270:	learn: 17.8116625	total: 515ms	remaining: 435ms
# 271:	learn: 17.6210798	total: 517ms	remaining: 433ms
# 272:	learn: 17.6048054	total: 518ms	remaining: 431ms
# 273:	learn: 17.4849398	total: 520ms	remaining: 429ms
# 274:	learn: 17.3722466	total: 522ms	remaining: 427ms
# 275:	learn: 17.1729244	total: 523ms	remaining: 425ms
# 276:	learn: 16.8947950	total: 525ms	remaining: 423ms
# 277:	learn: 16.6714289	total: 527ms	remaining: 421ms
# 278:	learn: 16.4243719	total: 529ms	remaining: 419ms
# 279:	learn: 16.2630348	total: 530ms	remaining: 417ms
# 280:	learn: 15.9835806	total: 532ms	remaining: 415ms
# 281:	learn: 15.8027269	total: 534ms	remaining: 413ms
# 282:	learn: 15.7851841	total: 536ms	remaining: 411ms
# 283:	learn: 15.5564431	total: 537ms	remaining: 409ms
# 284:	learn: 15.3535429	total: 539ms	remaining: 407ms
# 285:	learn: 15.1757522	total: 541ms	remaining: 405ms
# 286:	learn: 15.0416492	total: 543ms	remaining: 403ms
# 287:	learn: 14.8737644	total: 546ms	remaining: 402ms
# 288:	learn: 14.7029211	total: 550ms	remaining: 402ms
# 289:	learn: 14.6136437	total: 552ms	remaining: 400ms
# 290:	learn: 14.5982825	total: 554ms	remaining: 398ms
# 291:	learn: 14.5801042	total: 555ms	remaining: 396ms
# 292:	learn: 14.5706833	total: 558ms	remaining: 394ms
# 293:	learn: 14.4163552	total: 560ms	remaining: 392ms
# 294:	learn: 14.1865428	total: 562ms	remaining: 390ms
# 295:	learn: 14.0786594	total: 563ms	remaining: 388ms
# 296:	learn: 13.9088507	total: 565ms	remaining: 386ms
# 297:	learn: 13.7519691	total: 567ms	remaining: 384ms
# 298:	learn: 13.6496469	total: 569ms	remaining: 382ms
# 299:	learn: 13.5818320	total: 570ms	remaining: 380ms
# 300:	learn: 13.4537729	total: 572ms	remaining: 378ms
# 301:	learn: 13.3324624	total: 575ms	remaining: 377ms
# 302:	learn: 13.3197185	total: 576ms	remaining: 375ms
# 303:	learn: 13.2575741	total: 578ms	remaining: 373ms
# 304:	learn: 13.1386700	total: 580ms	remaining: 371ms
# 305:	learn: 13.1299205	total: 581ms	remaining: 369ms
# 306:	learn: 13.0344049	total: 583ms	remaining: 367ms
# 307:	learn: 12.9324144	total: 585ms	remaining: 364ms
# 308:	learn: 12.7959788	total: 587ms	remaining: 363ms
# 309:	learn: 12.6292194	total: 590ms	remaining: 362ms
# 310:	learn: 12.4893686	total: 592ms	remaining: 360ms
# 311:	learn: 12.3924302	total: 594ms	remaining: 358ms
# 312:	learn: 12.1881268	total: 596ms	remaining: 356ms
# 313:	learn: 12.0833827	total: 598ms	remaining: 354ms
# 314:	learn: 12.0315058	total: 600ms	remaining: 352ms
# 315:	learn: 12.0203275	total: 601ms	remaining: 350ms
# 316:	learn: 11.8821412	total: 603ms	remaining: 348ms
# 317:	learn: 11.8732612	total: 605ms	remaining: 346ms
# 318:	learn: 11.7747933	total: 607ms	remaining: 344ms
# 319:	learn: 11.6715515	total: 608ms	remaining: 342ms
# 320:	learn: 11.5376618	total: 610ms	remaining: 340ms
# 321:	learn: 11.4558208	total: 612ms	remaining: 338ms
# 322:	learn: 11.3611007	total: 613ms	remaining: 336ms
# 323:	learn: 11.2350746	total: 615ms	remaining: 334ms
# 324:	learn: 11.1956928	total: 617ms	remaining: 332ms
# 325:	learn: 11.1113106	total: 618ms	remaining: 330ms
# 326:	learn: 10.9578303	total: 620ms	remaining: 328ms
# 327:	learn: 10.8593397	total: 624ms	remaining: 327ms
# 328:	learn: 10.7784194	total: 626ms	remaining: 325ms
# 329:	learn: 10.6725852	total: 628ms	remaining: 323ms
# 330:	learn: 10.5891510	total: 629ms	remaining: 321ms
# 331:	learn: 10.4602921	total: 631ms	remaining: 319ms
# 332:	learn: 10.3883106	total: 632ms	remaining: 317ms
# 333:	learn: 10.3474715	total: 634ms	remaining: 315ms
# 334:	learn: 10.3080164	total: 635ms	remaining: 313ms
# 335:	learn: 10.2151519	total: 637ms	remaining: 311ms
# 336:	learn: 10.0949900	total: 638ms	remaining: 309ms
# 337:	learn: 10.0781993	total: 640ms	remaining: 307ms
# 338:	learn: 10.0365893	total: 641ms	remaining: 305ms
# 339:	learn: 9.9410902	total: 643ms	remaining: 302ms
# 340:	learn: 9.8167759	total: 644ms	remaining: 300ms
# 341:	learn: 9.7799895	total: 646ms	remaining: 298ms
# 342:	learn: 9.7515813	total: 647ms	remaining: 296ms
# 343:	learn: 9.7278669	total: 649ms	remaining: 294ms
# 344:	learn: 9.6502667	total: 650ms	remaining: 292ms
# 345:	learn: 9.5250037	total: 652ms	remaining: 290ms
# 346:	learn: 9.3987464	total: 654ms	remaining: 288ms
# 347:	learn: 9.3277308	total: 655ms	remaining: 286ms
# 348:	learn: 9.2345509	total: 657ms	remaining: 284ms
# 349:	learn: 9.1504497	total: 658ms	remaining: 282ms
# 350:	learn: 9.0815844	total: 660ms	remaining: 280ms
# 351:	learn: 9.0013312	total: 662ms	remaining: 278ms
# 352:	learn: 8.8669141	total: 663ms	remaining: 276ms
# 353:	learn: 8.8609190	total: 665ms	remaining: 274ms
# 354:	learn: 8.7607472	total: 667ms	remaining: 272ms
# 355:	learn: 8.6677902	total: 668ms	remaining: 270ms
# 356:	learn: 8.6205318	total: 670ms	remaining: 268ms
# 357:	learn: 8.5060024	total: 672ms	remaining: 266ms
# 358:	learn: 8.4305815	total: 673ms	remaining: 264ms
# 359:	learn: 8.3975091	total: 675ms	remaining: 262ms
# 360:	learn: 8.2967328	total: 676ms	remaining: 260ms
# 361:	learn: 8.2677143	total: 678ms	remaining: 258ms
# 362:	learn: 8.2512411	total: 680ms	remaining: 257ms
# 363:	learn: 8.2355967	total: 682ms	remaining: 255ms
# 364:	learn: 8.2165422	total: 684ms	remaining: 253ms
# 365:	learn: 8.1951856	total: 686ms	remaining: 251ms
# 366:	learn: 8.1605598	total: 688ms	remaining: 249ms
# 367:	learn: 8.1300319	total: 690ms	remaining: 248ms
# 368:	learn: 8.0491342	total: 693ms	remaining: 246ms
# 369:	learn: 8.0437310	total: 695ms	remaining: 244ms
# 370:	learn: 7.9797447	total: 697ms	remaining: 242ms
# 371:	learn: 7.8766639	total: 699ms	remaining: 240ms
# 372:	learn: 7.7679630	total: 700ms	remaining: 238ms
# 373:	learn: 7.6894879	total: 702ms	remaining: 236ms
# 374:	learn: 7.5914777	total: 703ms	remaining: 234ms
# 375:	learn: 7.5241150	total: 705ms	remaining: 232ms
# 376:	learn: 7.4534771	total: 707ms	remaining: 231ms
# 377:	learn: 7.3913372	total: 708ms	remaining: 229ms
# 378:	learn: 7.2887592	total: 710ms	remaining: 227ms
# 379:	learn: 7.2264893	total: 711ms	remaining: 225ms
# 380:	learn: 7.2067576	total: 714ms	remaining: 223ms
# 381:	learn: 7.1059919	total: 716ms	remaining: 221ms
# 382:	learn: 6.9735503	total: 718ms	remaining: 219ms
# 383:	learn: 6.9591914	total: 720ms	remaining: 217ms
# 384:	learn: 6.8587092	total: 722ms	remaining: 216ms
# 385:	learn: 6.8461056	total: 723ms	remaining: 214ms
# 386:	learn: 6.7399724	total: 725ms	remaining: 212ms
# 387:	learn: 6.6310091	total: 726ms	remaining: 210ms
# 388:	learn: 6.5676438	total: 728ms	remaining: 208ms
# 389:	learn: 6.4573055	total: 729ms	remaining: 206ms
# 390:	learn: 6.4358330	total: 731ms	remaining: 204ms
# 391:	learn: 6.4028770	total: 732ms	remaining: 202ms
# 392:	learn: 6.3491174	total: 734ms	remaining: 200ms
# 393:	learn: 6.3333085	total: 736ms	remaining: 198ms
# 394:	learn: 6.3292825	total: 738ms	remaining: 196ms
# 395:	learn: 6.2890103	total: 740ms	remaining: 194ms
# 396:	learn: 6.2288972	total: 742ms	remaining: 193ms
# 397:	learn: 6.1308858	total: 744ms	remaining: 191ms
# 398:	learn: 6.1256885	total: 745ms	remaining: 189ms
# 399:	learn: 6.1200138	total: 747ms	remaining: 187ms
# 400:	learn: 6.0827789	total: 749ms	remaining: 185ms
# 401:	learn: 6.0031710	total: 751ms	remaining: 183ms
# 402:	learn: 5.9153398	total: 752ms	remaining: 181ms
# 403:	learn: 5.9048319	total: 754ms	remaining: 179ms
# 404:	learn: 5.8978537	total: 755ms	remaining: 177ms
# 405:	learn: 5.8246529	total: 757ms	remaining: 175ms
# 406:	learn: 5.7666353	total: 759ms	remaining: 173ms
# 407:	learn: 5.7413210	total: 760ms	remaining: 171ms
# 408:	learn: 5.7007100	total: 762ms	remaining: 169ms
# 409:	learn: 5.6922350	total: 763ms	remaining: 168ms
# 410:	learn: 5.6387550	total: 765ms	remaining: 166ms
# 411:	learn: 5.5994193	total: 766ms	remaining: 164ms
# 412:	learn: 5.5311626	total: 768ms	remaining: 162ms
# 413:	learn: 5.4885562	total: 770ms	remaining: 160ms
# 414:	learn: 5.4335603	total: 772ms	remaining: 158ms
# 415:	learn: 5.3660805	total: 773ms	remaining: 156ms
# 416:	learn: 5.3187824	total: 775ms	remaining: 154ms
# 417:	learn: 5.2803327	total: 776ms	remaining: 152ms
# 418:	learn: 5.2598449	total: 778ms	remaining: 150ms
# 419:	learn: 5.2179130	total: 779ms	remaining: 148ms
# 420:	learn: 5.1624131	total: 781ms	remaining: 147ms
# 421:	learn: 5.1203931	total: 783ms	remaining: 145ms
# 422:	learn: 5.1128356	total: 784ms	remaining: 143ms
# 423:	learn: 5.0998547	total: 786ms	remaining: 141ms
# 424:	learn: 5.0201017	total: 788ms	remaining: 139ms
# 425:	learn: 4.9300922	total: 789ms	remaining: 137ms
# 426:	learn: 4.8989992	total: 791ms	remaining: 135ms
# 427:	learn: 4.8295440	total: 793ms	remaining: 133ms
# 428:	learn: 4.7467519	total: 794ms	remaining: 131ms
# 429:	learn: 4.6895910	total: 796ms	remaining: 130ms
# 430:	learn: 4.6823873	total: 797ms	remaining: 128ms
# 431:	learn: 4.6094204	total: 799ms	remaining: 126ms
# 432:	learn: 4.5816124	total: 801ms	remaining: 124ms
# 433:	learn: 4.5397041	total: 802ms	remaining: 122ms
# 434:	learn: 4.5198901	total: 804ms	remaining: 120ms
# 435:	learn: 4.5078706	total: 806ms	remaining: 118ms
# 436:	learn: 4.4475241	total: 813ms	remaining: 117ms
# 437:	learn: 4.3943383	total: 815ms	remaining: 115ms
# 438:	learn: 4.3912609	total: 816ms	remaining: 113ms
# 439:	learn: 4.3876284	total: 818ms	remaining: 112ms
# 440:	learn: 4.3343343	total: 819ms	remaining: 110ms
# 441:	learn: 4.2981239	total: 821ms	remaining: 108ms
# 442:	learn: 4.2560762	total: 823ms	remaining: 106ms
# 443:	learn: 4.2239269	total: 824ms	remaining: 104ms
# 444:	learn: 4.1853046	total: 826ms	remaining: 102ms
# 445:	learn: 4.1707240	total: 827ms	remaining: 100ms
# 446:	learn: 4.1119866	total: 829ms	remaining: 98.3ms
# 447:	learn: 4.0677024	total: 831ms	remaining: 96.4ms
# 448:	learn: 4.0073104	total: 833ms	remaining: 94.6ms
# 449:	learn: 3.9725824	total: 834ms	remaining: 92.7ms
# 450:	learn: 3.9239129	total: 836ms	remaining: 90.8ms
# 451:	learn: 3.9211943	total: 837ms	remaining: 88.9ms
# 452:	learn: 3.8852339	total: 839ms	remaining: 87ms
# 453:	learn: 3.8613158	total: 841ms	remaining: 85.2ms
# 454:	learn: 3.8126572	total: 842ms	remaining: 83.3ms
# 455:	learn: 3.7757526	total: 844ms	remaining: 81.5ms
# 456:	learn: 3.7291985	total: 846ms	remaining: 79.6ms
# 457:	learn: 3.7205678	total: 848ms	remaining: 77.7ms
# 458:	learn: 3.6889057	total: 849ms	remaining: 75.9ms
# 459:	learn: 3.6493443	total: 851ms	remaining: 74ms
# 460:	learn: 3.6039698	total: 853ms	remaining: 72.1ms
# 461:	learn: 3.5620972	total: 854ms	remaining: 70.3ms
# 462:	learn: 3.5220960	total: 856ms	remaining: 68.4ms
# 463:	learn: 3.4928664	total: 857ms	remaining: 66.5ms
# 464:	learn: 3.4827573	total: 859ms	remaining: 64.7ms
# 465:	learn: 3.4495617	total: 861ms	remaining: 62.8ms
# 466:	learn: 3.4157482	total: 863ms	remaining: 61ms
# 467:	learn: 3.3691192	total: 865ms	remaining: 59.1ms
# 468:	learn: 3.3663653	total: 866ms	remaining: 57.3ms
# 469:	learn: 3.3370359	total: 868ms	remaining: 55.4ms
# 470:	learn: 3.2829461	total: 869ms	remaining: 53.5ms
# 471:	learn: 3.2650200	total: 871ms	remaining: 51.7ms
# 472:	learn: 3.2355733	total: 873ms	remaining: 49.8ms
# 473:	learn: 3.1974036	total: 875ms	remaining: 48ms
# 474:	learn: 3.1642259	total: 876ms	remaining: 46.1ms
# 475:	learn: 3.1226311	total: 878ms	remaining: 44.3ms
# 476:	learn: 3.1016076	total: 880ms	remaining: 42.4ms
# 477:	learn: 3.0570121	total: 883ms	remaining: 40.6ms
# 478:	learn: 3.0266148	total: 885ms	remaining: 38.8ms
# 479:	learn: 3.0197505	total: 887ms	remaining: 36.9ms
# 480:	learn: 2.9855002	total: 888ms	remaining: 35.1ms
# 481:	learn: 2.9613972	total: 890ms	remaining: 33.2ms
# 482:	learn: 2.9328977	total: 891ms	remaining: 31.4ms
# 483:	learn: 2.9124377	total: 893ms	remaining: 29.5ms
# 484:	learn: 2.9014099	total: 894ms	remaining: 27.7ms
# 485:	learn: 2.8860976	total: 896ms	remaining: 25.8ms
# 486:	learn: 2.8479718	total: 897ms	remaining: 24ms
# 487:	learn: 2.8189381	total: 899ms	remaining: 22.1ms
# 488:	learn: 2.7963317	total: 901ms	remaining: 20.3ms
# 489:	learn: 2.7644733	total: 903ms	remaining: 18.4ms
# 490:	learn: 2.7513913	total: 904ms	remaining: 16.6ms
# 491:	learn: 2.7388783	total: 906ms	remaining: 14.7ms
# 492:	learn: 2.7065549	total: 908ms	remaining: 12.9ms
# 493:	learn: 2.7034766	total: 909ms	remaining: 11ms
# 494:	learn: 2.6722110	total: 911ms	remaining: 9.2ms
# 495:	learn: 2.6407165	total: 912ms	remaining: 7.36ms
# 496:	learn: 2.6365240	total: 914ms	remaining: 5.51ms
# 497:	learn: 2.6060884	total: 915ms	remaining: 3.67ms
# 498:	learn: 2.5935642	total: 917ms	remaining: 1.84ms
# 499:	learn: 2.5561729	total: 919ms	remaining: 0us
# RMSE (After): 219.5299 (CatBoost)
# CatBoost best params: {'depth': 6, 'iterations': 500, 'learning_rate': 0.1}

# %%
################################################
# Feature Importance
################################################

def plot_importance(model, features, num=len(X), save=False):
    feature_imp = pd.DataFrame({'Value': model.feature_importances_, 'Feature': features.columns})
    plt.figure(figsize=(10, 10))
    sns.set(font_scale=1)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value",
                                                                     ascending=False)[0:num])
    plt.title('Features')
    plt.tight_layout()
    plt.show()
    if save:
        plt.savefig('importances.png')


plot_importance(rf_final, X)
plot_importance(gbm_final, X)
plot_importance(lgbm_final, X)
plot_importance(catboost_final, X)

# %%
################################################
# Analyzing Model Complexity with Learning Curves
#################################################

def val_curve_params(model, X, y, param_name, param_range, scoring="roc_auc", cv=10):
    train_score, test_score = validation_curve(
        model, X=X, y=y, param_name=param_name, param_range=param_range, scoring=scoring, cv=cv)

    mean_train_score = np.mean(train_score, axis=1)
    mean_test_score = np.mean(test_score, axis=1)

    plt.plot(param_range, mean_train_score,
             label="Training Score", color='b')

    plt.plot(param_range, mean_test_score,
             label="Validation Score", color='g')

    plt.title(f"Validation Curve for {type(model).__name__}")
    plt.xlabel(f"Number of {param_name}")
    plt.ylabel(f"{scoring}")
    plt.tight_layout()
    plt.legend(loc='best')
    plt.show()


rf_val_params = [["max_depth", [5, 8, 15, 20, 30, None]],
                 ["max_features", [3, 5, 7, "auto"]],
                 ["min_samples_split", [2, 5, 8, 15, 20]],
                 ["n_estimators", [10, 50, 100, 200, 500]]]


rf_model = RandomForestRegressor(random_state=17)

for i in range(len(rf_val_params)):
    val_curve_params(rf_model, X, y, rf_val_params[i][0], rf_val_params[i][1],scoring="neg_mean_absolute_error")

rf_val_params[0][1]
# Out:
# [5, 8, 15, 20, 30, None]
